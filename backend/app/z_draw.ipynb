# %%
import os
import sys
# 這樣可以在 Notebook 裡使用
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from app.graph import app as langgraph_app
from IPython.display import Image

# 畫出流程圖成 PNG 圖檔
langgraph_app.get_graph().draw_mermaid_png()
Image(langgraph_app.get_graph().draw_mermaid_png())

# print(langgraph_app.get_graph().draw_ascii())
